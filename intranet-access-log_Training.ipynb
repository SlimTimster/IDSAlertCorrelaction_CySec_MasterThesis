# %%
import pandas as pd
import numpy as np

from helpers.data_helper import load_true_labels
from helpers.intranet_access_log_helper import train_log_classifier, extract_features, create_sequence_features, create_lstm_model

# %%
# PATHS 

# 1. santos | intranet_server | apache2 | intranet.smith.santos.com.access.log 
path_santos = "../AIT_LD-v2/santos"
path_log_file = "/gather/intranet_server/logs/apache2/intranet.smith.santos.com-access.log"
path_true_labels = "/labels/intranet_server/logs/apache2/intranet.smith.santos.com-access.log"

# %%
# Define the column names for the log format
columns = ['ip', 'logname', 'username', 'timestamp', 'requestmethod', 'statuscode', 'responsesize', 'referrer', 'user_agent']

# Read the log file with space as delimiter
df_raw = pd.read_csv(
    path_santos + path_log_file,
    sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])',
    engine='python',
    header=None,
    names=columns,
    na_values='-',
    quoting=3
)

# Post-process the timestamp and request method columns
# Remove brackets from timestamp
df_raw['timestamp'] = df_raw['timestamp'].str.strip('[]')

# Split the request method column (which contains "GET /path HTTP/1.1")
# Create new columns for method, path, and protocol
df_raw[['method', 'path', 'protocol']] = df_raw['requestmethod'].str.strip('"').str.split(' ', n=2, expand=True)

# Drop the original requestmethod column
#df_raw = df_raw.drop('requestmethod', axis=1)

df_raw.head()
# Out:
#                ip  logname  username                   timestamp  \
# 0  172.21.128.119      NaN       NaN  17/Jan/2022:06:25:38 +0000
# 1  172.21.128.119      NaN       NaN  17/Jan/2022:06:26:38 +0000
# 2  172.21.128.119      NaN       NaN  17/Jan/2022:06:27:38 +0000
# 3  172.21.128.119      NaN       NaN  17/Jan/2022:06:28:38 +0000
# 4  172.21.128.119      NaN       NaN  17/Jan/2022:06:29:38 +0000
#
#                               requestmethod  statuscode  responsesize  \
# 0  "POST /wp-admin/admin-ajax.php HTTP/1.1"         200          3598
# 1  "POST /wp-admin/admin-ajax.php HTTP/1.1"         200          1171
# 2  "POST /wp-admin/admin-ajax.php HTTP/1.1"         200          1171
# 3  "POST /wp-admin/admin-ajax.php HTTP/1.1"         200          1171
# 4  "POST /wp-admin/admin-ajax.php HTTP/1.1"         200          1171
#
#                                             referrer  \
# 0  "https://intranet.smith.santos.com/wp-admin/up...
# 1  "https://intranet.smith.santos.com/wp-admin/up...
# 2  "https://intranet.smith.santos.com/wp-admin/up...
# 3  "https://intranet.smith.santos.com/wp-admin/up...
# 4  "https://intranet.smith.santos.com/wp-admin/up...
#
#                                           user_agent method  \
# 0  "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:86...   POST
# 1  "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:86...   POST
# 2  "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:86...   POST
# 3  "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:86...   POST
# 4  "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:86...   POST
#
#                        path  protocol
# 0  /wp-admin/admin-ajax.php  HTTP/1.1
# 1  /wp-admin/admin-ajax.php  HTTP/1.1
# 2  /wp-admin/admin-ajax.php  HTTP/1.1
# 3  /wp-admin/admin-ajax.php  HTTP/1.1
# 4  /wp-admin/admin-ajax.php  HTTP/1.1

# %%
# Load true labels
true_labels = load_true_labels(path_santos + path_true_labels)

true_labels
# Out:
#       line                                   labels  \
# 0      431                 [service_scan, foothold]
# 1      432                 [service_scan, foothold]
# 2      433  [attacker_http, foothold, service_scan]
# 3      434  [attacker_http, foothold, service_scan]
# 4      435  [attacker_http, foothold, service_scan]
# ...    ...                                      ...
# 7789  8221  [attacker_http, foothold, webshell_cmd]
# 7790  8222                 [webshell_cmd, escalate]
# 7791  8223                 [webshell_cmd, escalate]
# 7792  8224                 [webshell_cmd, escalate]
# 7793  8322                 [webshell_cmd, escalate]
#
#                                                   rules
# 0     {'service_scan': ['attacker.service_scan'], 'f...
# 1     {'service_scan': ['attacker.service_scan'], 'f...
# 2     {'attacker_http': ['attacker.foothold.apache.a...
# 3     {'attacker_http': ['attacker.foothold.apache.a...
# 4     {'attacker_http': ['attacker.foothold.apache.a...
# ...                                                 ...
# 7789  {'attacker_http': ['attacker.foothold.apache.a...
# 7790  {'webshell_cmd': ['attacker.escalate.webshell....
# 7791  {'webshell_cmd': ['attacker.escalate.webshell....
# 7792  {'webshell_cmd': ['attacker.escalate.webshell....
# 7793  {'webshell_cmd': ['attacker.escalate.webshell....
#
# [7794 rows x 3 columns]

# %%
df_raw
# Out:
#                   ip  logname  username                   timestamp  \
# 0     172.21.128.119      NaN       NaN  17/Jan/2022:06:25:38 +0000
# 1     172.21.128.119      NaN       NaN  17/Jan/2022:06:26:38 +0000
# 2     172.21.128.119      NaN       NaN  17/Jan/2022:06:27:38 +0000
# 3     172.21.128.119      NaN       NaN  17/Jan/2022:06:28:38 +0000
# 4     172.21.128.119      NaN       NaN  17/Jan/2022:06:29:38 +0000
# ...              ...      ...       ...                         ...
# 9457  172.21.128.119      NaN       NaN  17/Jan/2022:20:26:02 +0000
# 9458  172.21.128.119      NaN       NaN  17/Jan/2022:20:26:02 +0000
# 9459  172.21.128.119      NaN       NaN  17/Jan/2022:20:26:02 +0000
# 9460  172.21.128.119      NaN       NaN  17/Jan/2022:20:26:31 +0000
# 9461  172.21.128.119      NaN       NaN  17/Jan/2022:20:26:40 +0000
#
#                                           requestmethod  statuscode  \
# 0              "POST /wp-admin/admin-ajax.php HTTP/1.1"         200
# 1              "POST /wp-admin/admin-ajax.php HTTP/1.1"         200
# 2              "POST /wp-admin/admin-ajax.php HTTP/1.1"         200
# 3              "POST /wp-admin/admin-ajax.php HTTP/1.1"         200
# 4              "POST /wp-admin/admin-ajax.php HTTP/1.1"         200
# ...                                                 ...         ...
# 9457  "GET /wp-content/plugins/wpdiscuz/assets/img/l...         200
# 9458           "POST /wp-admin/admin-ajax.php HTTP/1.1"         200
# 9459           "POST /wp-admin/admin-ajax.php HTTP/1.1"         200
# 9460           "POST /wp-admin/admin-ajax.php HTTP/1.1"         200
# 9461                                   "GET / HTTP/1.1"         200
#
#       responsesize                                           referrer  \
# 0             3598  "https://intranet.smith.santos.com/wp-admin/up...
# 1             1171  "https://intranet.smith.santos.com/wp-admin/up...
# 2             1171  "https://intranet.smith.santos.com/wp-admin/up...
# 3             1171  "https://intranet.smith.santos.com/wp-admin/up...
# 4             1171  "https://intranet.smith.santos.com/wp-admin/up...
# ...            ...                                                ...
# 9457          4069  "https://intranet.smith.santos.com/wp-content/...
# 9458          5673           "https://intranet.smith.santos.com/?p=5"
# 9459           540           "https://intranet.smith.santos.com/?p=5"
# 9460          1230           "https://intranet.smith.santos.com/?p=5"
# 9461          6137                                                "-"
#
#                                              user_agent method  \
# 0     "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:86...   POST
# 1     "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:86...   POST
# 2     "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:86...   POST
# 3     "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:86...   POST
# 4     "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:86...   POST
# ...                                                 ...    ...
# 9457  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...    GET
# 9458  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...   POST
# 9459  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...   POST
# 9460  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...   POST
# 9461  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...    GET
#
#                                                    path  protocol
# 0                              /wp-admin/admin-ajax.php  HTTP/1.1
# 1                              /wp-admin/admin-ajax.php  HTTP/1.1
# 2                              /wp-admin/admin-ajax.php  HTTP/1.1
# 3                              /wp-admin/admin-ajax.php  HTTP/1.1
# 4                              /wp-admin/admin-ajax.php  HTTP/1.1
# ...                                                 ...       ...
# 9457  /wp-content/plugins/wpdiscuz/assets/img/loadin...  HTTP/1.1
# 9458                           /wp-admin/admin-ajax.php  HTTP/1.1
# 9459                           /wp-admin/admin-ajax.php  HTTP/1.1
# 9460                           /wp-admin/admin-ajax.php  HTTP/1.1
# 9461                                                  /  HTTP/1.1
#
# [9462 rows x 12 columns]

# %%
df_raw.describe()
# Out:
#        logname  username   statuscode   responsesize
# count      0.0       0.0  9462.000000    9462.000000
# mean       NaN       NaN   367.807123    4388.614458
# std        NaN       NaN    77.887448   31888.408164
# min        NaN       NaN   200.000000       0.000000
# 25%        NaN       NaN   404.000000     146.000000
# 50%        NaN       NaN   404.000000     363.000000
# 75%        NaN       NaN   404.000000     363.000000
# max        NaN       NaN   500.000000  569760.000000

# %%
# Change object types to strings

df_raw['ip'] = df_raw['ip'].astype(str)
df_raw['timestamp'] = df_raw['timestamp'].astype(str)
df_raw['requestmethod'] = df_raw['requestmethod'].astype(str)
df_raw['referrer'] = df_raw['referrer'].astype(str)
df_raw['user_agent'] = df_raw['user_agent'].astype(str)
df_raw['method'] = df_raw['method'].astype(str)
df_raw['path'] = df_raw['path'].astype(str)
df_raw['protocol'] = df_raw['protocol'].astype(str)

# Drop username and logname (never used)
df_raw.drop(['username', 'logname'], axis=1, inplace=True)

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9462 entries, 0 to 9461
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ip             9462 non-null   object
#  1   timestamp      9462 non-null   object
#  2   requestmethod  9462 non-null   object
#  3   statuscode     9462 non-null   int64
#  4   responsesize   9462 non-null   int64
#  5   referrer       9462 non-null   object
#  6   user_agent     9462 non-null   object
#  7   method         9462 non-null   object
#  8   path           9462 non-null   object
#  9   protocol       9462 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 739.3+ KB

# %%
df_features, encoders = extract_features(df_raw)

df_features
# Out:
#       method_encoded  path_encoded  protocol_encoded  statuscode  \
# 0                  4          4505                 1         200
# 1                  4          4505                 1         200
# 2                  4          4505                 1         200
# 3                  4          4505                 1         200
# 4                  4          4505                 1         200
# ...              ...           ...               ...         ...
# 9457               1          4925                 1         200
# 9458               4          4505                 1         200
# 9459               4          4505                 1         200
# 9460               4          4505                 1         200
# 9461               1             1                 1         200
#
#       responsesize  path_length  has_php  has_wp  is_scan
# 0             3598           24        1       1        0
# 1             1171           24        1       1        0
# 2             1171           24        1       1        0
# 3             1171           24        1       1        0
# 4             1171           24        1       1        0
# ...            ...          ...      ...     ...      ...
# 9457          4069           51        0       1        0
# 9458          5673           24        1       1        0
# 9459           540           24        1       1        0
# 9460          1230           24        1       1        0
# 9461          6137            1        0       0        0
#
# [9462 rows x 9 columns]

# %%
# Create sequences
window_size = 10
X = create_sequence_features(df_features, window_size)

X
# Out:
# array([[[   4, 4505,    1, ...,    1,    1,    0],
#         [   4, 4505,    1, ...,    1,    1,    0],
#         [   4, 4505,    1, ...,    1,    1,    0],
#         ...,
#         [   1,    1,    1, ...,    0,    0,    0],
#         [   1, 7764,    1, ...,    0,    1,    0],
#         [   1, 6426,    1, ...,    0,    1,    0]],
#
#        [[   4, 4505,    1, ...,    1,    1,    0],
#         [   4, 4505,    1, ...,    1,    1,    0],
#         [   4, 4505,    1, ...,    1,    1,    0],
#         ...,
#         [   1, 7764,    1, ...,    0,    1,    0],
#         [   1, 6426,    1, ...,    0,    1,    0],
#         [   1, 7794,    1, ...,    0,    1,    0]],
#
#        [[   4, 4505,    1, ...,    1,    1,    0],
#         [   4, 4505,    1, ...,    1,    1,    0],
#         [   4, 4505,    1, ...,    1,    1,    0],
#         ...,
#         [   1, 6426,    1, ...,    0,    1,    0],
#         [   1, 7794,    1, ...,    0,    1,    0],
#         [   1, 6428,    1, ...,    0,    1,    0]],
#
#        ...,
#
#        [[   1, 4942,    1, ...,    0,    1,    0],
#         [   1, 4940,    1, ...,    0,    1,    0],
#         [   1, 7751,    1, ...,    0,    1,    0],
#         ...,
#         [   1, 4925,    1, ...,    0,    1,    0],
#         [   4, 4505,    1, ...,    1,    1,    0],
#         [   4, 4505,    1, ...,    1,    1,    0]],
#
#        [[   1, 4940,    1, ...,    0,    1,    0],
#         [   1, 7751,    1, ...,    0,    1,    0],
#         [   1, 7794,    1, ...,    0,    1,    0],
#         ...,
#         [   4, 4505,    1, ...,    1,    1,    0],
#         [   4, 4505,    1, ...,    1,    1,    0],
#         [   4, 4505,    1, ...,    1,    1,    0]],
#
#        [[   1, 7751,    1, ...,    0,    1,    0],
#         [   1, 7794,    1, ...,    0,    1,    0],
#         [   1, 6428,    1, ...,    0,    1,    0],
#         ...,
#         [   4, 4505,    1, ...,    1,    1,    0],
#         [   4, 4505,    1, ...,    1,    1,    0],
#         [   1,    1,    1, ...,    0,    0,    0]]], dtype=int64)

# %%
# Prepare labels
y = np.array(true_labels)

y
# Out:
# array([[431, list(['service_scan', 'foothold']),
#         {'service_scan': ['attacker.service_scan'], 'foothold': ['attacker.service_scan']}],
#        [432, list(['service_scan', 'foothold']),
#         {'service_scan': ['attacker.service_scan'], 'foothold': ['attacker.service_scan']}],
#        [433, list(['attacker_http', 'foothold', 'service_scan']),
#         {'attacker_http': ['attacker.foothold.apache.access'], 'foothold': ['attacker.foothold.apache.access', 'attacker.service_scan'], 'service_scan': ['attacker.service_scan']}],
#        ...,
#        [8223, list(['webshell_cmd', 'escalate']),
#         {'webshell_cmd': ['attacker.escalate.webshell.cmd.http_prepare_crack'], 'escalate': ['attacker.escalate.webshell.cmd.http_prepare_crack']}],
#        [8224, list(['webshell_cmd', 'escalate']),
#         {'webshell_cmd': ['attacker.escalate.webshell.cmd.http_prepare_crack'], 'escalate': ['attacker.escalate.webshell.cmd.http_prepare_crack']}],
#        [8322, list(['webshell_cmd', 'escalate']),
#         {'webshell_cmd': ['attacker.escalate.webshell.cmd.http_prepare_crack'], 'escalate': ['attacker.escalate.webshell.cmd.http_prepare_crack']}]],
#       dtype=object)

# %%
# Create and train model
input_shape = (window_size, X.shape[2])
num_classes = y.shape[1]  # number of label classes

model = create_lstm_model(input_shape, num_classes)

model
# Out:
# c:\Users\timgi\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# <Sequential name=sequential, built=True>

# %%
# Split data #TODO: Use data_helper instead
train_split = int(len(X) * 0.8)
X_train, X_test = X[:train_split], X[train_split:]
y_train, y_test = y[:train_split], y[train_split:]

# Train
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=10,
    batch_size=32
)


# TODO: Hier weiter und nochmal die features durchgehen!!!
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 7
#       4 y_train, y_test = y[:train_split], y[train_split:]
#       6 # Train
# ----> 7 history = model.fit(
#       8     X_train, y_train,
#       9     validation_data=(X_test, y_test),
#      10     epochs=10,
#      11     batch_size=32
#      12 )
#
# File c:\Users\timgi\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\timgi\anaconda3\Lib\site-packages\tensorflow\python\framework\constant_op.py:108, in convert_to_eager_tensor(value, ctx, dtype)
#     106     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     107 ctx.ensure_initialized()
# --> 108 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type int).

# %%
# Train model
model, history, encoders = train_log_classifier(df_raw, true_labels)

# Make predictions
new_logs = [...] # New log lines
predictions = predict_sequences(model, new_logs, encoders)# Load your data
log_data = [...] # Your log lines
labels = [...] # Your labels

# Train model
model, history, encoders = train_log_classifier(log_data, labels)

# Make predictions
new_logs = [...] # New log lines
predictions = predict_sequences(model, new_logs, encoders)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Train model
# ----> 2 model, history, encoders = train_log_classifier(df_raw, true_labels)
#       4 # Make predictions
#       5 new_logs = [...] # New log lines
#
# File d:\Timba\Studium\Masterarbeit\Repo\IDSAlertCorrelaction_CySec_MasterThesis\helpers\intranet_access_log_helper.py:93, in train_log_classifier(log_data, labels, window_size)
#      90 logs_df = pd.DataFrame([parse_log_line(line) for line in log_data])
#      92 # Extract features
# ---> 93 features_df, encoders = extract_features(logs_df)
#      95 # Create sequences
#      96 X = create_sequence_features(features_df, window_size)
#
# File d:\Timba\Studium\Masterarbeit\Repo\IDSAlertCorrelaction_CySec_MasterThesis\helpers\intranet_access_log_helper.py:44, in extract_features(df)
#      42 # First ensure we have method, path, protocol by splitting requestmethod if not already done
#      43 if 'method' not in df.columns:
# ---> 44     df[['method', 'path', 'protocol']] = df['requestmethod'].str.strip('"').str.split(' ', n=2, expand=True)
#      46 # Encode categorical variables
#      47 label_encoders = {}
#
# File c:\Users\timgi\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\timgi\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'requestmethod'

# %%
df_raw.describe()
# Out:
#        identity  user       status           size
# count       0.0   0.0  9462.000000    9462.000000
# mean        NaN   NaN   367.807123    4388.614458
# std         NaN   NaN    77.887448   31888.408164
# min         NaN   NaN   200.000000       0.000000
# 25%         NaN   NaN   404.000000     146.000000
# 50%         NaN   NaN   404.000000     363.000000
# 75%         NaN   NaN   404.000000     363.000000
# max         NaN   NaN   500.000000  569760.000000

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9462 entries, 0 to 9461
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ip          9462 non-null   object
#  1   identity    0 non-null      float64
#  2   user        0 non-null      float64
#  3   datetime    9462 non-null   object
#  4   request     9462 non-null   object
#  5   status      9462 non-null   int64
#  6   size        9462 non-null   int64
#  7   referer     9462 non-null   object
#  8   user_agent  9462 non-null   object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 665.4+ KB

# %%
# Remove the rows with missing values
df_raw = df_raw.drop(["identity", "user"], axis=1)

df_raw.describe()
# Out:
#             status           size
# count  9462.000000    9462.000000
# mean    367.807123    4388.614458
# std      77.887448   31888.408164
# min     200.000000       0.000000
# 25%     404.000000     146.000000
# 50%     404.000000     363.000000
# 75%     404.000000     363.000000
# max     500.000000  569760.000000

# %%
df_raw.isnull().sum()
# Out:
# ip            0
# datetime      0
# request       0
# status        0
# size          0
# referer       0
# user_agent    0
# dtype: int64

# %%
df_raw.duplicated().sum()
# Out:
# 5

# %%
# Check duplicates

df_raw[df_raw.duplicated()]
# Out:
#                    ip                      datetime request  status  size  \
# 40    192.168.104.125  [17/Jan/2022:06:36:12 +0000]     "-"     408  3002
# 8245    192.168.104.4  [17/Jan/2022:11:43:19 +0000]     "-"     408  3002
# 8246    192.168.104.4  [17/Jan/2022:11:43:19 +0000]     "-"     408  3002
# 9313    192.168.104.4  [17/Jan/2022:18:39:44 +0000]     "-"     408  3002
# 9375  192.168.104.141  [17/Jan/2022:18:56:51 +0000]     "-"     408  3002
#
#      referer user_agent
# 40       "-"        "-"
# 8245     "-"        "-"
# 8246     "-"        "-"
# 9313     "-"        "-"
# 9375     "-"        "-"

# %%
df_true_labels = load_true_labels(path_santos + path_true_labels)

df_true_labels.head(10)
# Out:
#    line                                   labels  \
# 0   431                 [service_scan, foothold]
# 1   432                 [service_scan, foothold]
# 2   433  [attacker_http, foothold, service_scan]
# 3   434  [attacker_http, foothold, service_scan]
# 4   435  [attacker_http, foothold, service_scan]
# 5   436  [attacker_http, foothold, service_scan]
# 6   437  [attacker_http, foothold, service_scan]
# 7   438  [attacker_http, foothold, service_scan]
# 8   439  [attacker_http, foothold, service_scan]
# 9   440  [attacker_http, foothold, service_scan]
#
#                                                rules
# 0  {'service_scan': ['attacker.service_scan'], 'f...
# 1  {'service_scan': ['attacker.service_scan'], 'f...
# 2  {'attacker_http': ['attacker.foothold.apache.a...
# 3  {'attacker_http': ['attacker.foothold.apache.a...
# 4  {'attacker_http': ['attacker.foothold.apache.a...
# 5  {'attacker_http': ['attacker.foothold.apache.a...
# 6  {'attacker_http': ['attacker.foothold.apache.a...
# 7  {'attacker_http': ['attacker.foothold.apache.a...
# 8  {'attacker_http': ['attacker.foothold.apache.a...
# 9  {'attacker_http': ['attacker.foothold.apache.a...

# %%
# Notes about the log lines (santos):
# - First two big blocks of nmap and WPscan scans
# - Webshell upload: 3 messages (8191 - 8193): 2x GET then POST /wp-admin/admin-ajax.php HTTP/1.1
# - There are more lines with sus IP (172.21.128.119) which are not labeled as attacks

# %%
# Manually extract extra features

# Possible features:

# o Request
#  - IP address 
#  - request_path
#  - request_method
#  - response status codes (maybe even patterns e.g. many 404s followed by a 200?)
#  - path_analysis -> len, depth, has query
#  - payload analysis: Base64 encoded content, sql_patterns (maybe True / false if found) | select, insert, update, delete, union, join ?CHECK, CITE
#  - suspicious_file_extensions (true / false) | php, asp, exe, dll, sh, bat ?CHECK, CITE
#  - Time based: frequency, intervals
# o Response
#  - response_size
#  - status_code
# o User Agent
#  - search for specific terms (bot, crawler, spider, scan, WPscan, curl, wget, python, perl) ?CHECK, CITE

# %%
# Log line structure:
# 1. Client IP Address
# 2. Logname (not used, always -)
# 3. User Name (not used, always -)
# 4. Timestamp format [DD7Mon/YYYY:HH:MM:SS +0000]
# 5. Request (method, path, protocol version): "GET /path/to/file HTTP/1.1"
# 6. Response Status Code: 200, 404 etc.
# 7. Response Size in Bytes: 100, 6137 etc.
# 8. Referrer (page that linked to this url): "https://intranet.smith.santos.com/", "-"
# 9. User Agent (browser, OS, device): 
#   "python-requests/2.27.1",
#    "WPScan v3.8.20 (https://wpscan.com/wordpress-security-scanner)",
#    "Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)"
